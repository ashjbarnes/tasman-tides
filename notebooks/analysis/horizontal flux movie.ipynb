# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import sys
sys.path.append("/home/149/ab8992/tasman-tides/")
import ttidelib as tt
import subprocess
import os
from importlib import reload
import xrft 
# %matplotlib inline
from dask.distributed import Client
client = Client()
client
# Out:
# Failed to connect to the remote Jupyter Server 'http://localhost:8888/'. Verify the server is running and reachable. (Failed to connect to the remote Jupyter Server 'http://localhost:8888/'. Verify the server is running and reachable. (Forbidden).).

# %% [markdown]
# ## Load the along beam data

# %%
output = "01*"
# eta = tt.beamgrid(xr.open_mfdataset(f"/g/data/nm03/ab8992/outputs/full-20/output{output}/surface.nc",decode_times = False).zos)
speed = tt.beamgrid(xr.open_mfdataset(f"/g/data/nm03/ab8992/outputs/full-20/output{output}/surface.nc",decode_times = False).speed)
u = xr.open_mfdataset(f"/g/data/nm03/ab8992/outputs/full-20/output{output}/u/*",decode_times = False).u
v = xr.open_mfdataset(f"/g/data/nm03/ab8992/outputs/full-20/output{output}/v/*",decode_times = False).v
e = xr.open_mfdataset(f"/g/data/nm03/ab8992/outputs/full-20/output{output}/e/*",decode_times = False).e
rho = xr.open_mfdataset(f"/g/data/nm03/ab8992/outputs/full-20/output{output}/rho/*",decode_times = False).rho
bathy = tt.beamgrid(xr.open_mfdataset(f"/g/data/nm03/ab8992/ttide-inputs/full-20/topog_raw.nc",decode_times = False).elevation,xname = "lon",yname = "lat")
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xesmf/frontend.py:696: UserWarning: Using dimensions ('yh', 'xh') from data variable speed as the horizontal dimensions for the regridding.
#   warnings.warn(

# %%
data["speed"].TIME.values[10]
# Out:
# 3663.0

# %%
data["speed"].TIME
# Out:
# <xarray.DataArray 'TIME' (TIME: 240)>
# array([3603., 3609., 3615., ..., 5025., 5031., 5037.])
# Coordinates:
#   * TIME     (TIME) float64 3.603e+03 3.609e+03 ... 5.031e+03 5.037e+03
# Attributes:
#     units:          hours since 2015-01-01 00:00:00
#     long_name:      time
#     axis:           T
#     calendar_type:  JULIAN
#     calendar:       julian
#     bounds:         time_bnds

# %%
from importlib import reload
reload(tt)
plt.clf()
data = xr.Dataset(
    {"speed":speed.rename({"time":"TIME"}), ## Rename since this dimension is on 6hrs
            "u":u,
            "v":v,
            "bathy":bathy
    }
)
fig = plt.figure(figsize=(15, 12))

tt.plot_ke(data,fig,10)
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:2026: UserWarning: The following kwargs were not used by contour: 'lineweight'
#   primitive = ax.contour(x, y, z, **kwargs)

# %%
reload(tt)
data = xr.Dataset(
    {"speed":speed.rename({"time":"TIME"}), ## Rename since this dimension is on 6hrs
            "u":u),
            "v":v),
            "bathy":bathy
    }
)

data

fig = plt.figure(figsize=(15, 12))

# tt.plot_hef(data,fig,50)
tt.make_movie(data,tt.plot_hef,fig,"full-20","test")
# Out:
# Making movie and writing to /g/data/v45/ab8992/dropbox/tasman-tides/full-20/movies/test/
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:2026: UserWarning: The following kwargs were not used by contour: 'lineweight'
#   primitive = ax.contour(x, y, z, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:348: UserWarning: The provided `plotfunc` does not provide the expected number of output arguments.            Expected a function `ax,pp =plotfunc(...)` but got %i output arguments. Inserting dummy values. This should not affect output.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:2026: UserWarning: The following kwargs were not used by contour: 'lineweight'
#   primitive = ax.contour(x, y, z, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:348: UserWarning: The provided `plotfunc` does not provide the expected number of output arguments.            Expected a function `ax,pp =plotfunc(...)` but got %i output arguments. Inserting dummy values. This should not affect output.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:2026: UserWarning: The following kwargs were not used by contour: 'lineweight'
#   primitive = ax.contour(x, y, z, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:348: UserWarning: The provided `plotfunc` does not provide the expected number of output arguments.            Expected a function `ax,pp =plotfunc(...)` but got %i output arguments. Inserting dummy values. This should not affect output.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# 2023-11-22 17:02:42,744 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:42,747 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:42,756 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:42,761 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:42,771 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:42,778 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:42,784 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:42,813 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:42,859 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:42,863 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:42,869 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:42,875 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:42,884 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:42,938 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:43,016 - distributed.nanny - WARNING - Restarting worker
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/ashley/Local_Scripts/tasman-tides/notebooks/analysis/horizontal flux movie.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/home/ashley/Local_Scripts/tasman-tides/notebooks/analysis/horizontal%20flux%20movie.ipynb#X44sZmlsZQ%3D%3D?line=11'>12</a> fig = plt.figure(figsize=(15, 12))
#      <a href='vscode-notebook-cell:/home/ashley/Local_Scripts/tasman-tides/notebooks/analysis/horizontal%20flux%20movie.ipynb#X44sZmlsZQ%3D%3D?line=13'>14</a> # tt.plot_hef(data,fig,50)
# ---> <a href='vscode-notebook-cell:/home/ashley/Local_Scripts/tasman-tides/notebooks/analysis/horizontal%20flux%20movie.ipynb#X44sZmlsZQ%3D%3D?line=14'>15</a> tt.make_movie(data,tt.plot_hef,fig,"full-20","test")
#
# File ~/tasman-tides/ttidelib.py:344, in make_movie(data, plot_function, fig, runname, plotname, plot_kwargs, framerate)
#     342 print(f"Making movie and writing to {outpath}")
#     343 mov = Movie(data,plot_function,input_check = False,plot_kwargs = plot_kwargs)
# --> 344 mov.save(outpath,overwrite_existing = True,parallel = False,parallel_compute_kwargs=dict(scheduler="processes", num_workers=28),framerate = framerate) # ,
#     345 print("finsished.")
#     346 return
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:552, in Movie.save(self, filename, remove_frames, remove_movie, progress, verbose, overwrite_existing, parallel, parallel_compute_kwargs, framerate, ffmpeg_options, gif_palette, gif_resolution_factor, gif_framerate)
#     548     self.save_frames_parallel(
#     549         dirname, parallel_compute_kwargs=parallel_compute_kwargs
#     550     )
#     551 else:
# --> 552     self.save_frames_serial(dirname, progress=progress)
#     554 # Create movie
#     555 combine_frames_into_movie(
#     556     dirname,
#     557     moviefile,
#    (...)
#     562     ffmpeg_options=ffmpeg_options,
#     563 )
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:388, in Movie.save_frames_serial(self, odir, progress)
#     385     warnings.warn("Cant show progess bar at this point. Install tqdm")
#     387 for timestep in frame_range:
# --> 388     fig, ax, pp = self.render_single_frame(timestep)
#     389     save_single_frame(
#     390         fig, timestep, odir=odir, frame_pattern=self.frame_pattern, dpi=self.dpi
#     391     )
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:353, in Movie.render_single_frame(self, timestep)
#     347 else:
#     348     warnings.warn(
#     349         "The provided `plotfunc` does not provide the expected number of output arguments.\
#     350     Expected a function `ax,pp =plotfunc(...)` but got %i output arguments. Inserting dummy values. This should not affect output. ",
#     351         UserWarning,
#     352     )
# --> 353     _ = self.plotfunc(self.data, fig, timestep, self.framedim, **self.kwargs)
#     354     ax, pp = None, None
#     355 return fig, ax, pp
#
# File ~/tasman-tides/ttidelib.py:353, in plot_hef(data, fig, i, framedim, **kwargs)
#     350 ax = fig.subplots(2,1)
#     352 time = data["speed"].TIME.values[i]
# --> 353 hef = calculate_hef(data["u"],data["v"],time = time)
#     354 exptname = "full-20" #TODO make this a kwarg
#     356 cmap = matplotlib.cm.get_cmap('RdBu')
#
# File ~/tasman-tides/ttidelib.py:271, in calculate_hef(u, v, time, total_only)
#     264 u_ = u.sel(
#     265         time = slice(time -  0.5 * averaging_window, time + 0.5 *  averaging_window)
#     266         ).chunk({"time":-1}).drop(["lat","lon"])
#     267 v_ = v.sel(
#     268         time = slice(time -  0.5 * averaging_window, time + 0.5 *  averaging_window)
#     269         ).chunk({"time":-1}).drop(["lat","lon"])
# --> 271 uf = m2filter(
#     272     u_,
#     273     m2f)
#     274 vf = m2filter(
#     275     v_,
#     276     m2f)
#     278 dux = u_.mean("time").differentiate("xb")
#
# File ~/tasman-tides/ttidelib.py:235, in m2filter(field, freq, tol)
#     233 FIELD = xrft.fft(field,dim = "time")
#     234 FIELD_filtered = FIELD.where(np.abs(np.abs(FIELD.freq_time) - freq) < tol,0)
# --> 235 return np.real(xrft.ifft(FIELD_filtered,dim = "freq_time"))
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:618, in ifft(daft, spacing_tol, dim, real_dim, shift, true_phase, true_amplitude, chunks_to_segments, prefix, lag, **kwargs)
#     616 diff = _diff_coord(daft[d])
#     617 delta = np.abs(diff[0])
# --> 618 l = _lag_coord(daft[d]) if d is not real_dim else daft[d][0].data
#     619 if not np.allclose(
#     620     diff, delta, rtol=spacing_tol
#     621 ):  # means that input is not on regular increasing grid
#     622     reordered_coord = daft[d].copy()
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:221, in _lag_coord(coord)
#     219 v0 = coord.values[0]
#     220 calendar = getattr(v0, "calendar", None)
# --> 221 if coord[-1] > coord[0]:
#     222     coord_data = coord.data
#     223 else:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/core/_typed_ops.py:283, in DataArrayOpsMixin.__gt__(self, other)
#     282 def __gt__(self, other: DaCompatible) -> Self:
# --> 283     return self._binary_op(other, operator.gt)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/core/dataarray.py:4672, in DataArray._binary_op(self, other, f, reflexive)
#    4665 other_coords = getattr(other, "coords", None)
#    4667 variable = (
#    4668     f(self.variable, other_variable_or_arraylike)
#    4669     if not reflexive
#    4670     else f(other_variable_or_arraylike, self.variable)
#    4671 )
# -> 4672 coords, indexes = self.coords._merge_raw(other_coords, reflexive)
#    4673 name = self._result_name(other)
#    4675 return self._replace(variable, coords, name, indexes=indexes)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/core/coordinates.py:468, in Coordinates._merge_raw(self, other, reflexive)
#     466 else:
#     467     coord_list = [self, other] if not reflexive else [other, self]
# --> 468     variables, indexes = merge_coordinates_without_align(coord_list)
#     469 return variables, indexes
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/core/merge.py:413, in merge_coordinates_without_align(objects, prioritized, exclude_dims, combine_attrs)
#     409     filtered = collected
#     411 # TODO: indexes should probably be filtered in collected elements
#     412 # before merging them
# --> 413 merged_coords, merged_indexes = merge_collected(
#     414     filtered, prioritized, combine_attrs=combine_attrs
#     415 )
#     416 merged_indexes = filter_indexes_from_coords(merged_indexes, set(merged_coords))
#     418 return merged_coords, merged_indexes
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/core/merge.py:290, in merge_collected(grouped, prioritized, compat, combine_attrs, equals)
#     288 variables = [variable for variable, _ in elements_list]
#     289 try:
# --> 290     merged_vars[name] = unique_variable(
#     291         name, variables, compat, equals.get(name, None)
#     292     )
#     293 except MergeError:
#     294     if compat != "minimal":
#     295         # we need more than "minimal" compatibility (for which
#     296         # we drop conflicting coordinates)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/core/merge.py:145, in unique_variable(name, variables, compat, equals)
#     141                 break
#     143 if not equals:
#     144     raise MergeError(
# --> 145         f"conflicting values for variable {name!r} on objects to be combined. "
#     146         "You can skip this check by specifying compat='override'."
#     147     )
#     149 if combine_method:
#     150     for var in variables[1:]:
#
# KeyboardInterrupt:
# 2023-11-22 17:02:43,886 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:43,888 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:43,894 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:43,897 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:43,910 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:43,913 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 17:02:43,923 - distributed.nanny - WARNING - Restarting worker

# %% [markdown]
# ## Kinetic Energy

# %%
# reload(tt)
data = xr.Dataset(
    {"speed":speed.rename({"time":"TIME"}), ## Rename since this dimension is on 6hrs
            "u":u.isel(time = slice(20,25)),
            "v":v.isel(time = slice(20,25)),
            "bathy":bathy
    }
)


fig = plt.figure(figsize=(15, 12))

# tt.plot_hef(data,fig,50)
tt.make_movie(data,tt.plot_ke,fig,"full-20","ke")
# Out:
# Making movie and writing to /g/data/v45/ab8992/dropbox/tasman-tides/full-20/movies/ke/
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:2026: UserWarning: The following kwargs were not used by contour: 'lineweight'
#   primitive = ax.contour(x, y, z, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:348: UserWarning: The provided `plotfunc` does not provide the expected number of output arguments.            Expected a function `ax,pp =plotfunc(...)` but got %i output arguments. Inserting dummy values. This should not affect output.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:2026: UserWarning: The following kwargs were not used by contour: 'lineweight'
#   primitive = ax.contour(x, y, z, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:348: UserWarning: The provided `plotfunc` does not provide the expected number of output arguments.            Expected a function `ax,pp =plotfunc(...)` but got %i output arguments. Inserting dummy values. This should not affect output.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:2026: UserWarning: The following kwargs were not used by contour: 'lineweight'
#   primitive = ax.contour(x, y, z, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:348: UserWarning: The provided `plotfunc` does not provide the expected number of output arguments.            Expected a function `ax,pp =plotfunc(...)` but got %i output arguments. Inserting dummy values. This should not affect output.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:2026: UserWarning: The following kwargs were not used by contour: 'lineweight'
#   primitive = ax.contour(x, y, z, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:348: UserWarning: The provided `plotfunc` does not provide the expected number of output arguments.            Expected a function `ax,pp =plotfunc(...)` but got %i output arguments. Inserting dummy values. This should not affect output.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:2026: UserWarning: The following kwargs were not used by contour: 'lineweight'
#   primitive = ax.contour(x, y, z, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:348: UserWarning: The provided `plotfunc` does not provide the expected number of output arguments.            Expected a function `ax,pp =plotfunc(...)` but got %i output arguments. Inserting dummy values. This should not affect output.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xrft/xrft.py:573: FutureWarning: Default ifft's behaviour (lag=None) changed! Default value of lag was zero (centered output coordinates) and is now set to transformed coordinate's attribute: 'direct_lag'.
#   warnings.warn(msg, FutureWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:2026: UserWarning: The following kwargs were not used by contour: 'lineweight'
#   primitive = ax.contour(x, y, z, **kwargs)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:136, in _check_ffmpeg_execute(command, verbose)
#     135 try:
# --> 136     p = _execute_command(command, verbose=verbose)
#     137     return p
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:124, in _execute_command(command, verbose, error)
#     123     if p.returncode != 0:
# --> 124         raise RuntimeError("Command %s failed" % command)
#     125 return p
#
# RuntimeError: Command ffmpeg -r 10 -i "/g/data/v45/ab8992/dropbox/tasman-tides/full-20/movies/ke/frame_%05d.png" -y -c:v libx264 -preset veryslow -crf 10 -pix_fmt yuv420p -r 10 "/g/data/v45/ab8992/dropbox/tasman-tides/full-20/movies/ke/" failed
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /home/ashley/Local_Scripts/tasman-tides/notebooks/analysis/horizontal flux movie.ipynb Cell 7 line 1
#      <a href='vscode-notebook-cell:/home/ashley/Local_Scripts/tasman-tides/notebooks/analysis/horizontal%20flux%20movie.ipynb#X53sZmlsZQ%3D%3D?line=10'>11</a> fig = plt.figure(figsize=(15, 12))
#      <a href='vscode-notebook-cell:/home/ashley/Local_Scripts/tasman-tides/notebooks/analysis/horizontal%20flux%20movie.ipynb#X53sZmlsZQ%3D%3D?line=12'>13</a> # tt.plot_hef(data,fig,50)
# ---> <a href='vscode-notebook-cell:/home/ashley/Local_Scripts/tasman-tides/notebooks/analysis/horizontal%20flux%20movie.ipynb#X53sZmlsZQ%3D%3D?line=13'>14</a> tt.make_movie(data,tt.plot_ke,fig,"full-20","ke")
#
# File ~/tasman-tides/ttidelib.py:364, in make_movie(data, plot_function, fig, runname, plotname, plot_kwargs, framerate)
#     362 print(f"Making movie and writing to {outpath}")
#     363 mov = Movie(data,plot_function,input_check = False,plot_kwargs = plot_kwargs)
# --> 364 mov.save(outpath,overwrite_existing = True,parallel = False,parallel_compute_kwargs=dict(scheduler="processes", num_workers=28),framerate = framerate) # ,
#     365 print("finsished.")
#     366 return
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:555, in Movie.save(self, filename, remove_frames, remove_movie, progress, verbose, overwrite_existing, parallel, parallel_compute_kwargs, framerate, ffmpeg_options, gif_palette, gif_resolution_factor, gif_framerate)
#     552     self.save_frames_serial(dirname, progress=progress)
#     554 # Create movie
# --> 555 combine_frames_into_movie(
#     556     dirname,
#     557     moviefile,
#     558     frame_pattern=self.frame_pattern,
#     559     remove_frames=remove_frames,
#     560     verbose=verbose,
#     561     framerate=framerate,
#     562     ffmpeg_options=ffmpeg_options,
#     563 )
#     565 # Create gif
#     566 if isgif:
#     567     # if ppath:
#     568     #     create_gif_palette(mpath, ppath=ppath, verbose=verbose)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:211, in combine_frames_into_movie(sourcefolder, moviename, frame_pattern, remove_frames, verbose, ffmpeg_options, framerate)
#     198 def combine_frames_into_movie(
#     199     sourcefolder,
#     200     moviename,
#    (...)
#     205     framerate=20,
#     206 ):
#     208     command = _combine_ffmpeg_command(
#     209         sourcefolder, moviename, framerate, frame_pattern, ffmpeg_options
#     210     )
# --> 211     p = _check_ffmpeg_execute(command, verbose=verbose)
#     213     print("Movie created at %s" % (moviename))
#     214     if remove_frames:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/xmovie/core.py:139, in _check_ffmpeg_execute(command, verbose)
#     137     return p
#     138 except RuntimeError:
# --> 139     raise RuntimeError(
#     140         "Something has gone wrong. Use `verbose=True` to check if ffmpeg displays a problem"
#     141     )
#
# RuntimeError: Something has gone wrong. Use `verbose=True` to check if ffmpeg displays a problem

# %% [markdown]
# ## Speed movie

# %%
output = "01*"
speed = xr.open_mfdataset(f"/g/data/nm03/ab8992/outputs/full-20/output{output}/surface_transect.nc",decode_times = False,chunks = {"time":1}).speed
if not os.path.exists("/g/data/nm03/ab8992/outputs/full-20/bathy_transect.nc"):
    bathy = tt.beamgrid(xr.open_mfdataset(f"/g/data/nm03/ab8992/ttide-inputs/full-20/topog_raw.nc",decode_times = False).elevation,xname = "lon",yname = "lat")
    bathy.elevation.to_netcdf("/g/data/nm03/ab8992/outputs/full-20/bathy_transect.nc")
else:
    bathy = xr.open_dataset("/g/data/nm03/ab8992/outputs/full-20/bathy_transect.nc")

# %%
bathy.elevation.to_netcdf("/g/data/nm03/ab8992/outputs/full-20/bathy_transect.nc")
RuntimeError: Command ffmpeg -r 10 -i "/g/data/v45/ab8992/dropbox/tasman-tides/plot_surfacespeed/movies/speed/frame_%05d.png" -y -c:v libx264 -preset veryslow -crf 10 -pix_fmt yuv420p -r 10 "/g/data/v45/ab8992/dropbox/tasman-tides/plot_surfacespeed/movies/speed/" failed

# %%
reload(tt)
import ttidelib as tt
data = xr.Dataset(
    {"speed":speed, ## Rename since this dimension is on 6hrs
            "bathy":bathy.elevation
    }
)


fig = plt.figure(figsize=(15, 12))

# tt.plot_hef(data,fig,50)
tt.make_movie(data,tt.plot_surfacespeed,fig,"plot_surfacespeed","speed",parallel=True)
# Out:
# Making movie and writing to /g/data/v45/ab8992/dropbox/tasman-tides/plot_surfacespeed/movies/speed/
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/dask/base.py:1402: UserWarning: Running on a single-machine scheduler when a distributed client is active might lead to unexpected results.
#   warnings.warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/xmovie/core.py:136, in _check_ffmpeg_execute(command, verbose)
#     135 try:
# --> 136     p = _execute_command(command, verbose=verbose)
#     137     return p
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/xmovie/core.py:124, in _execute_command(command, verbose, error)
#     123     if p.returncode != 0:
# --> 124         raise RuntimeError("Command %s failed" % command)
#     125 return p
#
# RuntimeError: Command ffmpeg -r 10 -i "/g/data/v45/ab8992/dropbox/tasman-tides/plot_surfacespeed/movies/speed/frame_%05d.png" -y -c:v libx264 -preset veryslow -crf 10 -pix_fmt yuv420p -r 10 "/g/data/v45/ab8992/dropbox/tasman-tides/plot_surfacespeed/movies/speed/" failed
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /home/ashley/Local_Scripts/tasman-tides/notebooks/analysis/horizontal flux movie.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell:/home/ashley/Local_Scripts/tasman-tides/notebooks/analysis/horizontal%20flux%20movie.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a> fig = plt.figure(figsize=(15, 12))
#      <a href='vscode-notebook-cell:/home/ashley/Local_Scripts/tasman-tides/notebooks/analysis/horizontal%20flux%20movie.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a> # tt.plot_hef(data,fig,50)
# ---> <a href='vscode-notebook-cell:/home/ashley/Local_Scripts/tasman-tides/notebooks/analysis/horizontal%20flux%20movie.ipynb#X14sZmlsZQ%3D%3D?line=12'>13</a> tt.make_movie(data,tt.plot_surfacespeed,fig,"plot_surfacespeed","speed",parallel=True)
#
# File ~/tasman-tides/ttidelib.py:329, in make_movie(data, plot_function, fig, runname, plotname, plot_kwargs, framerate, parallel)
#     327 print(f"Making movie and writing to {outpath}")
#     328 mov = Movie(data,plot_function,input_check = False,plot_kwargs = plot_kwargs)
# --> 329 mov.save(outpath,overwrite_existing = True,parallel = parallel,parallel_compute_kwargs=dict(scheduler="processes", num_workers=28),framerate = framerate) # ,
#     330 print("finsished.")
#     331 return
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/xmovie/core.py:555, in Movie.save(self, filename, remove_frames, remove_movie, progress, verbose, overwrite_existing, parallel, parallel_compute_kwargs, framerate, ffmpeg_options, gif_palette, gif_resolution_factor, gif_framerate)
#     552     self.save_frames_serial(dirname, progress=progress)
#     554 # Create movie
# --> 555 combine_frames_into_movie(
#     556     dirname,
#     557     moviefile,
#     558     frame_pattern=self.frame_pattern,
#     559     remove_frames=remove_frames,
#     560     verbose=verbose,
#     561     framerate=framerate,
#     562     ffmpeg_options=ffmpeg_options,
#     563 )
#     565 # Create gif
#     566 if isgif:
#     567     # if ppath:
#     568     #     create_gif_palette(mpath, ppath=ppath, verbose=verbose)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/xmovie/core.py:211, in combine_frames_into_movie(sourcefolder, moviename, frame_pattern, remove_frames, verbose, ffmpeg_options, framerate)
#     198 def combine_frames_into_movie(
#     199     sourcefolder,
#     200     moviename,
#    (...)
#     205     framerate=20,
#     206 ):
#     208     command = _combine_ffmpeg_command(
#     209         sourcefolder, moviename, framerate, frame_pattern, ffmpeg_options
#     210     )
# --> 211     p = _check_ffmpeg_execute(command, verbose=verbose)
#     213     print("Movie created at %s" % (moviename))
#     214     if remove_frames:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/xmovie/core.py:139, in _check_ffmpeg_execute(command, verbose)
#     137     return p
#     138 except RuntimeError:
# --> 139     raise RuntimeError(
#     140         "Something has gone wrong. Use `verbose=True` to check if ffmpeg displays a problem"
#     141     )
#
# RuntimeError: Something has gone wrong. Use `verbose=True` to check if ffmpeg displays a problem
