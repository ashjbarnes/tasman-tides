# %% [markdown]
# # Plot the horizontal kinetic energy of each mode along the beam path for different experiments

# %%
import sys
sys.path.append("/home/149/ab8992/tasman-tides/")
import xarray as xr
import ttidelib as tt
import scipy
import cmocean
import os
from pathlib import Path
cmap = cmocean.cm.dense_r
import matplotlib
import matplotlib.pyplot as plt
earth_cmap = matplotlib.colormaps["gist_earth"]
from datetime import timedelta

# import filtering
import numpy as np
import dask
dask.config.set({'logging.distributed': 'error'})
from dask.distributed import Client,default_client
import xrft


client = tt.startdask()
client
# Out:
# <Client: 'tcp://127.0.0.1:40947' processes=7 threads=28, memory=112.00 GiB>
# <Client: 'tcp://127.0.0.1:40947' processes=7 threads=28, memory=112.00 GiB>

# %% [markdown]
# ## First draft a function to calculate N(z)
#
# $ \large N = \frac{-g}{\rho}\frac{\partial \rho}{\partial z} $

# %%
trange = 50
to_process = {
    "full-20": {
        "data":tt.collect_data(
            exptname="full-20",
            rawdata = ["rho"],
            lfiltered = "10000-lowpass"
        ).sel(yb = slice(-50,50)).drop("cst").chunk({"zl":-1,"time":10}).persist()
        },
    "blank-20": {
        "data":tt.collect_data(
            exptname="blank-20",
            rawdata = ["rho","u","v"],
            timerange = (1000 - trange,1000 + trange)
        ).sel(yb = slice(-50,50))
    },
    "blank-20_filtered": {
        "data":tt.collect_data(
            exptname="blank-20",
            rawdata = ["rho"],
            lfiltered = "1000-lowpass"
        ).sel(yb = slice(-50,50)).drop("cst").chunk({"zl":-1,"time":10}).persist()
    },
    # "ideal-20": {
    #     "data":tt.collect_data(
    #         exptname="ideal-20",
    #         rawdata = ["rho","u","v"],
    #         timerange = (1000 - trange,1000 + trange)
    #     ).sel(yb = slice(-50,50)).isel(zl = slice(0,80))
    # },
    "smooth-20": {
        "data":tt.collect_data(
            exptname="smooth-20",
            rawdata = ["rho"],
            lfiltered = "10000-lowpass"
        ).sel(yb = slice(-50,50)).drop("cst").chunk({"zl":-1,"time":10}).persist()
        },
    }
# Out:
# Timerange as inferred from lfiltered data: (9950.0, 10049.0)
# loading rho...	done.
# /jobfs/116474488.gadi-pbs/ipykernel_4125190/82984304.py:8: DeprecationWarning: dropping variables using `drop` is deprecated; use drop_vars.
#   ).sel(yb = slice(-50,50)).drop("cst").chunk({"zl":-1,"time":10}).persist()
# loading rho...	done.
# loading u...	done.
# loading v...	done.
# Timerange as inferred from lfiltered data: (950.0, 1049.0)
# loading rho...	done.
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/array/core.py:4839: PerformanceWarning: Increasing number of chunks by factor of 81
#   result = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/array/core.py:4839: PerformanceWarning: Increasing number of chunks by factor of 81
#   result = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/array/core.py:4839: PerformanceWarning: Increasing number of chunks by factor of 81
#   result = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/array/core.py:4839: PerformanceWarning: Increasing number of chunks by factor of 81
#   result = blockwise(
# /jobfs/116474488.gadi-pbs/ipykernel_4125190/82984304.py:22: DeprecationWarning: dropping variables using `drop` is deprecated; use drop_vars.
#   ).sel(yb = slice(-50,50)).drop("cst").chunk({"zl":-1,"time":10}).persist()
# Timerange as inferred from lfiltered data: (9950.0, 10049.0)
# loading rho...	done.
# /jobfs/116474488.gadi-pbs/ipykernel_4125190/82984304.py:36: DeprecationWarning: dropping variables using `drop` is deprecated; use drop_vars.
#   ).sel(yb = slice(-50,50)).drop("cst").chunk({"zl":-1,"time":10}).persist()

# %%
for expt in to_process:
    print(expt)
    u = tt.VerticalModes(to_process[expt]["data"].isel(zl = slice(10,None)),"u")
    v = tt.VerticalModes(to_process[expt]["data"].isel(zl = slice(10,None)),"v")
    u_horiz = u.hztl
    u_vrtl = u.vrtl
    # v_horiz = (to_process[expt]["data"]["v"].fillna(0) * vrtl).integrate("zl")
    v_horiz = v.hztl
    v_vrtl = v.vrtl
    ## Now calculate the KE and integrate in time
    KE = 0.5 * (((u_vrtl * u_horiz)**2 + (v_vrtl * v_horiz)**2)).mean("time").integrate("yb")
    to_process[expt]["KE"] = KE.load()
    # get the time in the middle of dataset range
    midtime = int(round(np.mean(to_process[expt]["data"]["u"].time.values)))
    # tt.save(
    #     to_process[expt]["KE"],
    #     f"KE_alongbeam/KE-{midtime}.nc"
    #     )
# Out:
# full-20
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in sqrt
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in sqrt
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in sqrt
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in sqrt
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in sqrt
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in sqrt
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in sqrt
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/client.py:3161: UserWarning: Sending large graph of size 58.54 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# blank-20
# 2024-05-26 03:19:37,704 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-16abdc47ec9b4f5e7075b766f546eb2c' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d85c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a632e900>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('2593942ef99f74fe', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('036eec25918cc394', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:39,332 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-16abdc47ec9b4f5e7075b766f546eb2c' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d85c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7aa253900>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('2593942ef99f74fe', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('036eec25918cc394', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:40,939 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-d6577516bdcc017153ed9f4622823e0f' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d9e40>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a799671ec0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('042aef27d26a049b', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('dd05a38313dc11c4', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:42,448 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-600ec1e8a0ab9ece1d7da6d321c58916' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a733eec0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7aaf121c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('c3f09a0e580756ea', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('dc6b1fc97dfb917b', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:44,066 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-d52ecdb9e22c484cae1124e783f10a52' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d9040>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a797d4c580>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('29002a4b7278a865', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('d0db74028c8292cf', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:45,455 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-d52ecdb9e22c484cae1124e783f10a52' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d9040>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7aad74e40>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('29002a4b7278a865', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('d0db74028c8292cf', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:46,743 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-d52ecdb9e22c484cae1124e783f10a52' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d9040>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a799996300>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('29002a4b7278a865', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('d0db74028c8292cf', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:48,138 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-16abdc47ec9b4f5e7075b766f546eb2c' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d85c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a8d133c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('2593942ef99f74fe', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('036eec25918cc394', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:49,693 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-16abdc47ec9b4f5e7075b766f546eb2c' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d85c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7aa21ad00>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('2593942ef99f74fe', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('036eec25918cc394', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:51,142 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-16abdc47ec9b4f5e7075b766f546eb2c' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d85c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7943e9fc0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('2593942ef99f74fe', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('036eec25918cc394', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:52,627 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-16abdc47ec9b4f5e7075b766f546eb2c' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d85c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7b75dd600>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('2593942ef99f74fe', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('036eec25918cc394', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:53,866 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-d6577516bdcc017153ed9f4622823e0f' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d9e40>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7ab4dee80>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('042aef27d26a049b', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('dd05a38313dc11c4', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:55,238 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-600ec1e8a0ab9ece1d7da6d321c58916' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a733eec0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a79432b9c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('c3f09a0e580756ea', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('dc6b1fc97dfb917b', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:56,601 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-d52ecdb9e22c484cae1124e783f10a52' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d9040>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a79a0ba5c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('29002a4b7278a865', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('d0db74028c8292cf', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:57,904 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-d52ecdb9e22c484cae1124e783f10a52' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d9040>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7ab1505c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('29002a4b7278a865', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('d0db74028c8292cf', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:19:59,386 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-d52ecdb9e22c484cae1124e783f10a52' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d9040>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a797d7c180>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('29002a4b7278a865', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('d0db74028c8292cf', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:20:00,725 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-16abdc47ec9b4f5e7075b766f546eb2c' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d85c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7b503a540>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('2593942ef99f74fe', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('036eec25918cc394', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:20:02,203 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-16abdc47ec9b4f5e7075b766f546eb2c' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d85c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7942ebec0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('2593942ef99f74fe', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('036eec25918cc394', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:20:04,369 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-rho-16abdc47ec9b4f5e7075b766f546eb2c' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a75d85c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14a8a086e560>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14a7a528f180>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('2593942ef99f74fe', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('036eec25918cc394', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-05-26 03:24:43,966 - distributed.scheduler - ERROR - Couldn't gather keys: {('getitem-dc6bf84b9c814f782d9f801d733f5cce', 0): 'processing'}
# 2024-05-26 03:24:44,146 - distributed.scheduler - ERROR - Couldn't gather keys: {('getitem-dc6bf84b9c814f782d9f801d733f5cce', 0): 'processing'}
# 2024-05-26 03:24:44,319 - distributed.scheduler - ERROR - Couldn't gather keys: {('getitem-dc6bf84b9c814f782d9f801d733f5cce', 0): 'processing'}
# 2024-05-26 04:05:42,761 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46517' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-d4bd12fce0dd8607b40944f84bce4d01', 0, 9, 0, 0), ('rechunk-merge-ea29e6546d598498e67d75fba00bd9a0', 0, 7, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 8, 0, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 3, 0, 0, 0), ('rechunk-merge-694fdb03a5250bf405e16edbd5312180', 0, 3, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 0, 0, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 7, 0, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 2, 0, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 4, 0, 0, 0), ('getitem-f7f55c3a9f2b2337b8138c35776e3743', 0, 0), ('rechunk-merge-694fdb03a5250bf405e16edbd5312180', 0, 1, 0, 0), ('getitem-6303b9c542da3b49707b524e846b410a', 0, 0), ('rechunk-merge-caf334eba284bda6d70cf69c66fb19d5', 0, 9, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 5, 0, 0, 0), ('rechunk-merge-0c320761c70c65371f6ee9afaccf54aa', 0, 0, 0, 0), ('getitem-172d8c25f5a273a42126825d0ffd2174', 0, 0), ('rechunk-merge-694fdb03a5250bf405e16edbd5312180', 0, 5, 0, 0), ('rechunk-merge-d4bd12fce0dd8607b40944f84bce4d01', 0, 3, 0, 0), ('getitem-ed5824d004b6ecb87df23ab1318be433', 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 1, 0, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 9, 0, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 6, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1716660342.7586365')
# 2024-05-26 04:05:43,109 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39487' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-ec36f5301ed3fbc5e4ee3ddee6d6623e', 0, 0), ('rechunk-merge-d4bd12fce0dd8607b40944f84bce4d01', 0, 5, 0, 0), ('rechunk-merge-caf334eba284bda6d70cf69c66fb19d5', 0, 7, 0, 0), ('rechunk-merge-7a97c4e85cc0842101f3266826a33401', 0, 2, 0, 0), ('rechunk-merge-7a97c4e85cc0842101f3266826a33401', 0, 3, 0, 0), ('rechunk-merge-ea29e6546d598498e67d75fba00bd9a0', 0, 8, 0, 0), ('rechunk-merge-ea29e6546d598498e67d75fba00bd9a0', 0, 2, 0, 0), ('rechunk-merge-caf334eba284bda6d70cf69c66fb19d5', 0, 4, 0, 0), ('rechunk-merge-694fdb03a5250bf405e16edbd5312180', 0, 6, 0, 0), ('rechunk-merge-0c320761c70c65371f6ee9afaccf54aa', 0, 3, 0, 0)} (stimulus_id='handle-worker-cleanup-1716660343.1088252')
# 2024-05-26 04:05:43,356 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46763' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 5, 0, 2, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 4, 0, 2, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 8, 0, 2, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 1, 0, 2, 0), ('rechunk-merge-caf334eba284bda6d70cf69c66fb19d5', 0, 6, 0, 0), ('rechunk-merge-7a97c4e85cc0842101f3266826a33401', 0, 5, 0, 0), ('rechunk-merge-0c320761c70c65371f6ee9afaccf54aa', 0, 1, 0, 0), ('rechunk-merge-caf334eba284bda6d70cf69c66fb19d5', 0, 2, 0, 0), ('rechunk-merge-7a97c4e85cc0842101f3266826a33401', 0, 1, 0, 0), ('rechunk-merge-d4bd12fce0dd8607b40944f84bce4d01', 0, 8, 0, 0), ('rechunk-merge-0c320761c70c65371f6ee9afaccf54aa', 0, 2, 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 7, 0, 2, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 0, 0, 2, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 9, 0, 2, 0), ('rechunk-merge-d4bd12fce0dd8607b40944f84bce4d01', 0, 4, 0, 0), ('rechunk-merge-caf334eba284bda6d70cf69c66fb19d5', 0, 1, 0, 0), ('rechunk-merge-694fdb03a5250bf405e16edbd5312180', 0, 9, 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 6, 0, 2, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 3, 0, 2, 0), ('rechunk-merge-7a97c4e85cc0842101f3266826a33401', 0, 7, 0, 0), ('rechunk-merge-caf334eba284bda6d70cf69c66fb19d5', 0, 3, 0, 0), ('rechunk-merge-7a97c4e85cc0842101f3266826a33401', 0, 0, 0, 0), ('rechunk-merge-0c320761c70c65371f6ee9afaccf54aa', 0, 7, 0, 0), ('rechunk-merge-0c320761c70c65371f6ee9afaccf54aa', 0, 8, 0, 0), ('rechunk-merge-7a97c4e85cc0842101f3266826a33401', 0, 6, 0, 0), ('rechunk-merge-7a97c4e85cc0842101f3266826a33401', 0, 8, 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 2, 0, 2, 0)} (stimulus_id='handle-worker-cleanup-1716660343.3560472')
# 2024-05-26 04:05:43,771 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39145' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 2, 0, 4, 0), ('rechunk-merge-694fdb03a5250bf405e16edbd5312180', 0, 8, 0, 0), ('rechunk-merge-694fdb03a5250bf405e16edbd5312180', 0, 2, 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 8, 0, 4, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 1, 0, 4, 0), ('getitem-68f4faec78909b5c3b59b6d98695394f', 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 4, 0, 4, 0), ('rechunk-merge-ea29e6546d598498e67d75fba00bd9a0', 0, 1, 0, 0), ('rechunk-merge-694fdb03a5250bf405e16edbd5312180', 0, 0, 0, 0), ('rechunk-merge-d4bd12fce0dd8607b40944f84bce4d01', 0, 2, 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 7, 0, 4, 0), ('rechunk-merge-ea29e6546d598498e67d75fba00bd9a0', 0, 3, 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 0, 0, 4, 0), ('rechunk-merge-ea29e6546d598498e67d75fba00bd9a0', 0, 9, 0, 0), ('rechunk-merge-caf334eba284bda6d70cf69c66fb19d5', 0, 0, 0, 0), ('getitem-baf08ef7ae545f2e37743180a823f8c9', 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 6, 0, 4, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 3, 0, 4, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 9, 0, 4, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 5, 0, 4, 0), ('getitem-641c35f2c85011342cd67d6c239aef93', 0, 0), ('rechunk-merge-694fdb03a5250bf405e16edbd5312180', 0, 7, 0, 0)} (stimulus_id='handle-worker-cleanup-1716660343.7710683')
# 2024-05-26 04:05:43,938 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45659' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 4, 0, 4, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 4, 0, 3, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 8, 0, 1, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 2, 0, 3, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 9, 0, 1, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 1, 0, 1, 0), ('rechunk-merge-d4bd12fce0dd8607b40944f84bce4d01', 0, 0, 0, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 3, 0, 4, 0), ('rechunk-merge-7a97c4e85cc0842101f3266826a33401', 0, 4, 0, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 6, 0, 4, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 1, 0, 4, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 7, 0, 1, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 9, 0, 4, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 6, 0, 1, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 3, 0, 1, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 6, 0, 4, 0), ('rechunk-merge-d4bd12fce0dd8607b40944f84bce4d01', 0, 7, 0, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 5, 0, 4, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 9, 0, 1, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 8, 0, 4, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 5, 0, 1, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 2, 0, 1, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 4, 0, 1, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 0, 0, 4, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 3, 0, 4, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 0, 0, 4, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 5, 0, 3, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 2, 0, 4, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 6, 0, 1, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 2, 0, 4, 0), ('rechunk-merge-ea29e6546d598498e67d75fba00bd9a0', 0, 0, 0, 0), ('rechunk-merge-caf334eba284bda6d70cf69c66fb19d5', 0, 5, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 7, 0, 4, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 9, 0, 3, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 3, 0, 1, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 0, 0, 1, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 8, 0, 4, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 4, 0, 1, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 1, 0, 3, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 8, 0, 1, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 1, 0, 4, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 6, 0, 3, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 1, 0, 1, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 5, 0, 1, 0), ('rechunk-merge-0c320761c70c65371f6ee9afaccf54aa', 0, 6, 0, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 2, 0, 1, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 4, 0, 4, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 7, 0, 4, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 7, 0, 1, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 8, 0, 3, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 5, 0, 4, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 3, 0, 3, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 7, 0, 3, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 0, 0, 1, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 9, 0, 4, 0)} (stimulus_id='handle-worker-cleanup-1716660343.9374564')
# 2024-05-26 04:05:44,071 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39805' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 1, 0, 3, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 9, 0, 2, 0), ('rechunk-merge-0c320761c70c65371f6ee9afaccf54aa', 0, 9, 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 1, 0, 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 4, 0, 0, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 3, 0, 2, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 0, 0, 2, 0), ('rechunk-merge-0c320761c70c65371f6ee9afaccf54aa', 0, 5, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 6, 0, 2, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 3, 0, 2, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 1, 0, 2, 0), ('rechunk-merge-caf334eba284bda6d70cf69c66fb19d5', 0, 8, 0, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 5, 0, 0, 0), ('rechunk-merge-ea29e6546d598498e67d75fba00bd9a0', 0, 5, 0, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 2, 0, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 5, 0, 1, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 0, 0, 0, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 5, 0, 2, 0), ('rechunk-merge-694fdb03a5250bf405e16edbd5312180', 0, 4, 0, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 8, 0, 3, 0), ('rechunk-merge-d4bd12fce0dd8607b40944f84bce4d01', 0, 6, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 8, 0, 2, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 9, 0, 3, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 7, 0, 2, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 0, 0, 0, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 4, 0, 3, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 7, 0, 3, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 2, 0, 2, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 7, 0, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 2, 0, 2, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 8, 0, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 0, 0, 2, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 1, 0, 0, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 1, 0, 2, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 9, 0, 1, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 6, 0, 1, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 6, 0, 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 3, 0, 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 9, 0, 0, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 8, 0, 2, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 9, 0, 2, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 6, 0, 3, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 7, 0, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 1, 0, 1, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 7, 0, 1, 0), ('rechunk-merge-7a97c4e85cc0842101f3266826a33401', 0, 9, 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 4, 0, 2, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 8, 0, 1, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 5, 0, 3, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 9, 0, 0, 0), ('getitem-c5bdda9126e576c18b29579a85b59b32', 0, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 0, 0, 1, 0), ('rechunk-merge-ec8a97e11ab56cdba606a944066ae34d', 3, 0, 1, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 5, 0, 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 8, 0, 0, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 4, 0, 0, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 0, 0, 3, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 7, 0, 2, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa9e', 4, 0, 2, 0), ('rechunk-merge-6307f403f199d2412f5b4ac282fcfa ...
# 2024-05-26 04:05:44,221 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42355' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 5, 0, 3, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 2, 0, 3, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 6, 0, 3, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 0, 0, 3, 0), ('rechunk-merge-0c320761c70c65371f6ee9afaccf54aa', 0, 4, 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 8, 0, 3, 0), ('rechunk-merge-ea29e6546d598498e67d75fba00bd9a0', 0, 6, 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 1, 0, 3, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 9, 0, 3, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 3, 0, 3, 0), ('rechunk-merge-d4bd12fce0dd8607b40944f84bce4d01', 0, 1, 0, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 4, 0, 3, 0), ('rechunk-merge-89fff8b04b7ecb58c085e33915bb6561', 7, 0, 3, 0), ('rechunk-merge-ea29e6546d598498e67d75fba00bd9a0', 0, 4, 0, 0)} (stimulus_id='handle-worker-cleanup-1716660344.2212477')
# 2024-05-26 04:05:44,310 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:39145'.
# 2024-05-26 04:05:44,313 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:42355'.
# 2024-05-26 04:05:44,318 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:46763'.
# 2024-05-26 04:05:44,320 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:39487'.
# 2024-05-26 04:05:44,323 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:46517'.
# 2024-05-26 04:05:44,325 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:39805'.
# 2024-05-26 04:05:44,328 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:45659'.
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/client.py:3161: UserWarning: Sending large graph of size 58.31 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# blank-20_filtered
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/client.py:3161: UserWarning: Sending large graph of size 58.54 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# smooth-20
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/client.py:3161: UserWarning: Sending large graph of size 58.54 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
fig,ax = plt.subplots(5,figsize = (20,20))

for expt in to_process:
    if expt != "ideal-20":
        for i,mode in enumerate(range(1,10,2)):
            to_process[expt]["KE"].isel(mode = mode).integrate("zl").sel(xb = slice(0,1200)).plot(ax = ax[i],label = expt)

            ax[i].set_title(f"Mode {mode}")


            ax[i].legend()
            ax[i].set_ylabel("~Kinetic energy")
            ax[i].set_xlabel("")



ax[-1].set_xlabel("<-- Tassie  (km)  Macquarie Ridge -->")
# Out:
# Text(0.5, 0, '<-- Tassie  (km)  Macquarie Ridge -->')

# %%
fig, ax = plt.subplots(5, 2, figsize=(10, 30))

for i,mode in enumerate(range(1,6)):
    # Replace 'full_20_data[i]' and 'smooth_20_data[i]' with your actual data
    to_process["smooth-20"]["KE"].isel(mode = mode).sel(xb = slice(0,1200)).plot(ax = ax[i,0])
    to_process["full-20"]["KE"].isel(mode = mode).sel(xb = slice(0,1200)).plot(ax = ax[i,1])
    ax[i,0].fill_between(
        to_process["smooth-20"]["data"].bathy.xb,
        to_process["smooth-20"]["data"].bathy.sel(yb = 0,method = "nearest"),
        6000,color = "gray"
    )
    ax[i,1].fill_between(
        to_process["full-20"]["data"].bathy.xb,
        -1 * to_process["full-20"]["data"].bathy.sel(yb = 0,method = "nearest"),
        6000,color = "gray"
    )

    ax[i,0].invert_yaxis()
    ax[i,1].invert_yaxis()
    ax[i, 1].set_title(f'Mode {mode} - Full-20 Experiment')
    ax[i, 0].set_title(f'Mode {mode} - Smooth-20 Experiment')
    ax[i,0].set_xlabel("")
    ax[i,0].set_ylabel("")
    ax[i,1].set_ylabel("")
    ax[i,1].set_xlabel("")

plt.tight_layout()
plt.show()
# Out:
# 2024-05-26 03:24:43,968 - distributed.client - WARNING - Couldn't gather 1 keys, rescheduling (('getitem-dc6bf84b9c814f782d9f801d733f5cce', 0),)
# 2024-05-26 03:24:44,148 - distributed.client - WARNING - Couldn't gather 1 keys, rescheduling (('getitem-dc6bf84b9c814f782d9f801d733f5cce', 0),)
# 2024-05-26 03:24:44,321 - distributed.client - WARNING - Couldn't gather 1 keys, rescheduling (('getitem-dc6bf84b9c814f782d9f801d733f5cce', 0),)
# 2024-05-26 04:05:44,307 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/utils_comm.py", line 452, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/utils_comm.py", line 431, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:35658 remote=tcp://127.0.0.1:40947>: Stream is closed
# 2024-05-26 04:05:44,308 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/utils_comm.py", line 452, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/utils_comm.py", line 431, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:35648 remote=tcp://127.0.0.1:40947>: Stream is closed
# 2024-05-26 04:05:44,308 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/utils_comm.py", line 452, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/utils_comm.py", line 431, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:35642 remote=tcp://127.0.0.1:40947>: Stream is closed
# 2024-05-26 04:05:44,309 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/utils_comm.py", line 452, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/utils_comm.py", line 431, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:35670 remote=tcp://127.0.0.1:40947>: Stream is closed
# 2024-05-26 04:05:44,308 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/utils_comm.py", line 452, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/utils_comm.py", line 431, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:35656 remote=tcp://127.0.0.1:40947>: Stream is closed
# 2024-05-26 04:05:44,309 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/utils_comm.py", line 452, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/utils_comm.py", line 431, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:35644 remote=tcp://127.0.0.1:40947>: Stream is closed
# 2024-05-26 04:05:44,310 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/utils_comm.py", line 452, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/utils_comm.py", line 431, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:35666 remote=tcp://127.0.0.1:40947>: Stream is closed

# %%
fig, ax = plt.subplots(5, 2, figsize=(10, 30))

for i,mode in enumerate(range(1,6)):
    # Replace 'full_20_data[i]' and 'smooth_20_data[i]' with your actual data
    to_process["full-20"]["KE"].isel(mode = mode).sel(xb = slice(0,1200)).plot(ax = ax[i,0])
    to_process["smooth-20"]["KE"].isel(mode = mode).sel(xb = slice(0,1200)).plot(ax = ax[i,1])
    ax[i,1].fill_between(
        to_process["smooth-20"]["data"].bathy.xb,
        to_process["smooth-20"]["data"].bathy.sel(yb = 0,method = "nearest"),
        6000,color = "gray"
    )
    ax[i,0].fill_between(
        to_process["full-20"]["data"].bathy.xb,
        -1 * to_process["full-20"]["data"].bathy.sel(yb = 0,method = "nearest"),
        6000,color = "gray"
    )

    ax[i,0].invert_yaxis()
    ax[i,1].invert_yaxis()
    ax[i, 0].set_title(f'Mode {mode} - Full-20 Experiment')
    ax[i, 1].set_title(f'Mode {mode} - Smooth-20 Experiment')
    ax[i,0].set_xlabel("")
    ax[i,0].set_ylabel("")
    ax[i,1].set_ylabel("")
    ax[i,1].set_xlabel("")

plt.tight_layout()
plt.show()
# Out:
# 2024-05-25 23:10:16,850 - distributed.client - WARNING - Couldn't gather 1 keys, rescheduling (('getitem-dc6bf84b9c814f782d9f801d733f5cce', 0),)

# %% [markdown]
# ## Smooth experiment has heightened velocities near surface??

# %%
fig, ax = plt.subplots(2, figsize=(10, 15))


np.abs(to_process["full-20"]["data"].u).mean("time").sel(yb = 0,method = "nearest").sel(xb = slice(0,1200)).plot(ax = ax[0],vmax = 0.14)
np.abs(to_process["smooth-20"]["data"].u).mean("time").sel(yb = 0,method = "nearest").sel(xb = slice(0,1200)).plot(ax = ax[1])
ax[1].fill_between(
    to_process["smooth-20"]["data"].bathy.xb,
    to_process["smooth-20"]["data"].bathy.sel(yb = 0,method = "nearest"),
    6000,color = "gray"
)
ax[0].fill_between(
    to_process["full-20"]["data"].bathy.xb,
    -1 * to_process["full-20"]["data"].bathy.sel(yb = 0,method = "nearest"),
    6000,color = "gray"
)

ax[0].invert_yaxis()
ax[1].invert_yaxis()
ax[0].set_title(f'Full-20 Experiment')
ax[1].set_title(f'Smooth-20 Experiment')
ax[0].set_xlabel("")
ax[0].set_ylabel("")
ax[1].set_ylabel("")
ax[1].set_xlabel("")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(4, figsize=(10, 15))


to_process["full-20"]["data"].u.isel(time = 5,zl = 50).sel(xb = slice(0,1200)).plot(ax = ax[0])
to_process["smooth-20"]["data"].u.isel(time = 5,zl = 50).sel(xb = slice(0,1200)).plot(ax = ax[1])
to_process["blank-20"]["data"].u.isel(time = 5,zl = 50).sel(xb = slice(0,1200)).plot(ax = ax[2])
to_process["ideal-20"]["data"].u.isel(time = 5,zl = 50).sel(xb = slice(0,1200)).plot(ax = ax[3])
for i in range(4):
    tt.plot_topo(ax[i],to_process["full-20"]["data"].bathy)
    ax[i].set_xlim(0,1200)
    ax[i].set_xlabel("")
    ax[i].set_ylabel("")
ax[0].set_title(f'Full forcing (filtered)')
ax[1].set_title(f'Flat bottom (filtered)')
ax[2].set_title(f'Tide Only blank')
ax[3].set_title(f'Tide Only blank with flat bottom')
# fig.suptitle("Along Beam velocities at surface")
fig.suptitle("Along Beam velocities at 50th layer down")
# Out:
# Text(0.5, 0.98, 'Along Beam velocities at 50th layer down')

# %%
fig, ax = plt.subplots(2, figsize=(10, 15))
unfiltered_full = tt.collect_data("full-20",rawdata = ["u"],timerange = (40000-50,40000+50))
unfiltered_smooth = tt.collect_data("smooth-20",rawdata = ["u"],timerange = (10000-50,10000+50))

unfiltered_full.isel(time = 50,zl = slice(0,40)).u.sel(yb = 0,method = "nearest").sel(xb = slice(0,1200)).plot(ax = ax[0])
unfiltered_smooth.isel(time = 50,zl = slice(0,40)).u.sel(yb = 0,method = "nearest").sel(xb = slice(0,1200)).plot(ax = ax[1])
ax[1].fill_between(
    unfiltered_smooth.bathy.xb,
    unfiltered_smooth.bathy.sel(yb = 0,method = "nearest"),
    6000,color = "gray"
)
ax[0].fill_between(
    unfiltered_full.bathy.xb,
    -1 * unfiltered_full.bathy.sel(yb = 0,method = "nearest"),
    6000,color = "gray"
)

ax[0].invert_yaxis()
ax[1].invert_yaxis()
ax[0].set_title(f'Unfiltered full')
ax[1].set_title(f'Unfiltered Smooth')
ax[0].set_xlabel("")
ax[0].set_ylabel("")
ax[1].set_ylabel("")
ax[1].set_xlabel("")

plt.tight_layout()
plt.show()
# Out:
# loading u...	done.
# loading u...	done.

# %%
fig, ax = plt.subplots(2, figsize=(10, 15))

unfiltered_full.u.isel(time = 50).sel(zl = 50,method = "nearest").sel(xb = slice(0,1200)).plot(ax = ax[0],vmax = 1)
unfiltered_smooth.u.isel(time = 50).sel(zl = 50,method = "nearest").sel(xb = slice(0,1200)).plot(ax = ax[1],vmax = 1)
# ax[1].fill_between(
#     to_process["smooth-20"]["data"].bathy.xb,
#     to_process["smooth-20"]["data"].bathy.sel(yb = 0,method = "nearest"),
#     6000,color = "gray"
# )
# ax[0].fill_between(
#     to_process["full-20"]["data"].bathy.xb,
#     -1 * to_process["full-20"]["data"].bathy.sel(yb = 0,method = "nearest"),
#     6000,color = "gray"
# )

# ax[0].invert_yaxis()
# ax[1].invert_yaxis()
ax[0].set_title(f'Unfiltered full')
ax[1].set_title(f'Unfiltered Smooth')
ax[0].set_xlabel("")
ax[0].set_ylabel("")
ax[1].set_ylabel("")
ax[1].set_xlabel("")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(10, figsize=(10, 30))

for i,j in enumerate(range(5000,15000,1000)):
    unfiltered_full = tt.collect_data("full-20",rawdata = ["u"],timerange = (j-50,j+50))
    unfiltered_full.isel(time = 50).u.sel(yb = 0,method = "nearest").sel(xb = slice(0,1200)).isel(zl = slice(0,40)).plot(ax = ax[i])
    # ax[i].fill_between(
    #     unfiltered_full.bathy.xb,
    #     -1 * unfiltered_full.bathy.sel(yb = 0,method = "nearest"),
    #     6000,color = "gray"
    # )
    ax[i].set_title(f"t = {j}")
    ax[i].invert_yaxis()
    ax[i].set_xlabel("")
    ax[i].set_ylabel("")

fig.tight_layout()
# Out:
# loading u...	done.
# loading u...	done.
# loading u...	done.
# loading u...	done.
# loading u...	done.
# loading u...	done.
# loading u...	done.
# loading u...	done.
# loading u...	done.
# loading u...	done.

# %%
(25 * 15)

# %%
print(5000 / (24 * 15))
print(10000 / (24 * 15))
print(4 * 15 * 0.88)
print(4 * 15 * 0.77)
# Out:
# 13.88888888888889
# 27.77777777777778
# 52.8
# 46.2

# %%
taux1 = xr.open_mfdataset("/g/data/nm03/ab8992/outputs/full-20/output027/surface_transect.nc",decode_times = False)
taux2 = xr.open_mfdataset("/g/data/nm03/ab8992/outputs/full-20/output013/surface_transect.nc",decode_times = False)

# plot both of these
fig, ax = plt.subplots(2, figsize=(10, 15))
taux1.taux.isel(time = 46).plot(ax = ax[0])
taux2.taux.isel(time = 53).plot(ax = ax[1])

ax[0].set_title(f"Surface stress for t = 10000")
ax[1].set_title(f"Surface stress for t = 5000")
ax[0].set_xlabel(f"")
# Out:
# Text(0.5, 0, '')
